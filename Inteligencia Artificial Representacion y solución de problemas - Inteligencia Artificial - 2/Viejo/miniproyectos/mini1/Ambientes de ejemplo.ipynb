# %%
from AmbientesMP import *
from random import choice

# %% [markdown]
# ## El vendedor viajero

# %%
prob = Vendedor('Chapinero')
s = prob.estado_inicial
prob.pintar_estado(s)

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %% [markdown]
# ## Los europeos y los indígenas

# %%
prob = IndigenasEuropeos()
s = prob.estado_inicial
prob.pintar_estado(s)
# Out:
# <AxesSubplot:>

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2],[a,a1])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %% [markdown]
# ## Las torres de Hanoi

# %%
prob = Hannoi()
s = prob.estado_inicial
prob.pintar_estado(s)
# Out:
# <AxesSubplot:>

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %% [markdown]
# ## Criptoaritmética

# %%
prob = CriptoAritmetica(['send','more','money'])
s = prob.estado_inicial
prob.pintar_estado(s)
# Out:
# <AxesSubplot:>

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %% [markdown]
# ##  El mundo de los bloques

# %%
prob = BlockWorld()
s = prob.estado_inicial
prob.pintar_estado(s)
# Out:
# <AxesSubplot:>

# %%
acciones = prob.acciones_aplicables(s)
print(acciones)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %% [markdown]
# ## El camino del caballo

# %%
prob = nsquare_horses()
s = prob.estado_inicial
prob.pintar_estado(s)
# Out:
# <AxesSubplot:>

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %% [markdown]
# ## Parser

# %%
regla1 = ('S', 'aSb')
regla2 = ('S', 'AB')
regla3 = ('A', 'a')
regla4 = ('B', 'b')
gramatica = [regla1, regla2, regla3, regla4]
w = "aabb"
prob = Parser(gramatica, w)
s = prob.estado_inicial
prob.pintar_estado(s)
# Out:
# S

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])
# Out:
#      S
#   ___|___
#  |       A
#  |       |
#  B       a

# %%
prob.test_objetivo(s2)
# Out:
# {0: ('S', [1, 2]), 1: ('A', [3]), 2: ('B', []), 3: ('a', [])}
# []
# False

# %% [markdown]
# ### Prueba

# %%
# %load_ext autoreload
# %autoreload 2
from AmbientesMP import *
from random import choice
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
regla1 = ('S', 'aSb')
regla2 = ('S', 'AB')
regla3 = ('A', 'a')
regla4 = ('B', 'b')
gramatica = [regla1, regla2, regla3, regla4]

w = "aabb"
prob = Parser(gramatica, w)
s = prob.estado_inicial

# %%
for accion in prob.acciones_aplicables(s):
    new_state = prob.transicion(estado = s, accion = accion)
    #print(new_state)
    print(prob.test_objetivo(new_state))
    prob.pintar_estado(new_state)
    break
# Out:
# cadena ['a', 'S', 'b'], w aSb, self.w aabb
# False
#      S
#   ___|___
#  a   S   b

# %%
print(s)

for accion in prob.acciones_aplicables(s):
    new_state = prob.transicion(estado = s, accion = accion)
    print(new_state)
    break
# Out:
# {0: ('S', [])}
# 0
# {0: ('S', [1, 2, 3]), 1: ('a', []), 2: ('S', []), 3: ('b', [])}

# %%
def back_tracking(prob, state):
    
    
    if prob.test_objetivo(state):
        return [state]
    
    for action in prob.acciones_aplicables(state):
        
        new_state = prob.transicion(estado = state,
                                    accion = action)
        
        result = back_tracking(prob, new_state)
        
        if result != False:
            return  [] + result + [new_state]
        
    
    return False

# %%
ans = back_tracking(prob = prob, state = s)
ans.reverse()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_2992/952236624.py in <module>
# ----> 1 ans = back_tracking(prob = prob, state = s)
#       2 ans.reverse()
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# ...
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#      10                                     accion = action)
#      11
# ---> 12         result = back_tracking(prob, new_state)
#      13
#      14         if result != False:
#
# /tmp/ipykernel_2992/2281410636.py in back_tracking(prob, state)
#       2
#       3
# ----> 4     if prob.test_objetivo(state):
#       5         return [state]
#       6
#
# ~/Documents/univ/6toSemestre/ia/miniproyectos/mini1/AmbientesMP.py in test_objetivo(self, estado)
#    1590
#    1591     def test_objetivo(self, estado):
# -> 1592         arb = self.arbol(0, estado)
#    1593
#    1594         if type(arb) == str:
#
# ~/Documents/univ/6toSemestre/ia/miniproyectos/mini1/AmbientesMP.py in arbol(self, t, estado)
#    1521
#    1522         if len(hijos) > 0:
# -> 1523             return Tree(rotulo, [self.arbol(i, estado) for i in hijos])
#    1524         else:
#    1525             return rotulo
#
# ~/Documents/univ/6toSemestre/ia/miniproyectos/mini1/AmbientesMP.py in <listcomp>(.0)
#    1521
#    1522         if len(hijos) > 0:
# -> 1523             return Tree(rotulo, [self.arbol(i, estado) for i in hijos])
#    1524         else:
#    1525             return rotulo
#
# ... last 2 frames repeated, from the frame below ...
#
# ~/Documents/univ/6toSemestre/ia/miniproyectos/mini1/AmbientesMP.py in arbol(self, t, estado)
#    1521
#    1522         if len(hijos) > 0:
# -> 1523             return Tree(rotulo, [self.arbol(i, estado) for i in hijos])
#    1524         else:
#    1525             return rotulo
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
prob.pintar_camino(ans)
# Out:
#          S
#   _______|___
#  |   |       S
#  |   |    ___|___
#  a   b   a   S   b

# %%
prob.pintar_estado(ans[-1])
prob.test_objetivo(ans[-1])
# Out:
#          S
#   _______|___
#  |   |       S
#  |   |    ___|___
#  a   b   a   S   b
#
# {0: ('S', [1, 2, 3]), 1: ('a', []), 2: ('S', [4, 5, 6]), 3: ('b', []), 4: ('a', []), 5: ('S', []), 6: ('b', [])}
# ['a', 'a', 'b', 'b']
# True
